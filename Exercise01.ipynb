# %% [markdown]
# # <center>Big Data &ndash; Exercise 1</center>
# ## <center>Fall 2023 &ndash; Week 1 &ndash; ETH Zurich</center>

# %% [markdown]
# ### Aims
# - **After this exercise:**
#     - Understand the SQL language and its common query patterns.
#     - Understand the 'table' data shape, normalization, and when they can (and should) be used.
#     - be able to query data in tables with the SQL language.
# - **Later in the semester:**
#     - Relate these language features and query patterns relative to other data shapes, technologies, and the languages designed to query them.
#     - Understand when tables are not the appropriate shape for your data and when you can (and should) throw normalization away!

# %% [markdown]
# ### Prerequisites
# In this exercise, you will brush-up the fundamental concepts of relational databases and SQL. If you haven't taken an introductory databases course (or want to refresh your knowledge) we recommend you to read the following:
#
# Garcia-Molina, Ullman, Widom: Database Systems: The Complete Book. Pearson, 2. Edition, 2008. (Chapters 1, 2, 3, and 6) [Available in the ETH Library] [[Online]](https://ebookcentral.proquest.com/lib/ethz/detail.action?pq-origsite=primo&docID=5832965) [[Selected solutions]](http://infolab.stanford.edu/~ullman/dscbsols/sols.html).
#
# Or have a look at the recordings from Information Systems for Engineers - ETH Zurich, available on [[YouTube]](https://www.youtube.com/c/GhislainFournysLectures).

# %% [markdown]
# ### Database Set-up
# We will be once again working in the ExamMagicBox (you can find it in the following [[link]](http://please.add.link.here) if you have not downloaded it yet): please drag this Notebook in the folder. Just like last week, activate the docker container for the exercise sheet with `docker compose up`; please wait for the message `PostgreSQL init process complete; ready for start up` in the docker logs before proceeding! Alternatively you can start the Docker with `docker compose up -d` and wait for the command to execute: please note that you are creating the containers in the background this way. You can then type `docker compose down` when you are done.
#
# As before, we set up our connection to the database and enable use of `%sql` and `%%sql`.

# %%
server='db'
user='postgres'
password='example'
database='postgres'
connection_string=f'postgresql://{user}:{password}@{server}:5432/{database}'

# %%
# This line tells Jupyter Notebook to reload the SQL extension. 
# The SQL extension in Jupyter allows you to run SQL queries directly in a Jupyter Notebook cell. 
# %reload_ext sql
# %sql $connection_string

# %%
# %%sql
# SELECT version();
# Out:
#  * postgresql://postgres:***@db:5432/postgres
# 1 rows affected.
# [('PostgreSQL 16.0 (Debian 16.0-1.pgdg120+1) on x86_64-pc-linux-gnu, compiled by gcc (Debian 12.2.0-14) 12.2.0, 64-bit',)]

# %%
# %%sql
# Select
# from artists
# natural join released_by
# natural join releases
# where artist_id = '47742'
# Out:
#  * postgresql://postgres:***@db:5432/postgres
# 1 rows affected.
# [(47742, 'Diana Ross', 'Diane Ernestine Earle Ross', 'Born March 26, 1944, Detroit, Michigan, USA.\r American vocalist, producer, and occasional actress. Working within groups early on in her musical car ... (84 characters truncated) ... any genres; R&B, soul, disco, and jazz. Initial success came as lead singer of [a17966]. \r \r Sister to Motown songwriter [a=Arthur Ross]. \r \r \r ', 'http://www.myspace.com/dianaross')]

# %% [markdown]
# ### Origin of the data
# You can find more information on the dataset in the following links
# - [Discogs](https://www.discogs.com/)
# - [Discogs XML data dumps](http://data.discogs.com/)
#
# If you do not want to use Docker or it does not work you can download the dataset from this [link](https://cloud.inf.ethz.ch/s/DtjCHTLRHT39BRN/download/discogs.dump.xz), see `postgres-init.sh` to see how to import it)

# %% [markdown]
# ## Exercise 1: Explore the dataset
# We want to first understand the dataset a bit better. You will find some queries below to help you explore the schema.

# %% [markdown]
# ### List tables
# The following query retrieves a list of tables in the database from a system table describing the current database.

# %%
# %%sql
# SELECT table_name
# FROM information_schema.tables
# WHERE table_schema = 'public';
# Out:
#  * postgresql://postgres:***@db:5432/postgres
# 22 rows affected.
# [('companies',),
#  ('jobs',),
#  ('employees02',),
#  ('badges',),
#  ('comments',),
#  ('inventory',),
#  ('posthistory',),
#  ('postlinks',),
#  ('posts',),
#  ('tags',),
#  ('users',),
#  ('votes',),
#  ('artists',),
#  ('released_by',),
#  ('releases',),
#  ('tracks',),
#  ('employees',),
#  ('dept_manager',),
#  ('departments',),
#  ('dept_emp',),
#  ('titles',),
#  ('salaries',)]

# %% [markdown]
# ### List attributes/columns
# The following query retrieves a list of columns from the tables in the database.

# %%
# %%sql
# SELECT table_name, column_name, data_type, is_nullable, ordinal_position
# FROM information_schema.columns
# WHERE table_schema = 'public'
# AND table_name NOT LIKE 'pg_%'
# ORDER BY table_name, ordinal_position;
# Out:
#  * postgresql://postgres:***@db:5432/postgres
# 128 rows affected.
# [('artists', 'artist_id', 'integer', 'NO', 1),
#  ('artists', 'name', 'character varying', 'YES', 2),
#  ('artists', 'realname', 'text', 'YES', 3),
#  ('artists', 'profile', 'text', 'YES', 4),
#  ('artists', 'url', 'text', 'YES', 5),
#  ('badges', 'id', 'integer', 'NO', 1),
#  ('badges', 'userid', 'integer', 'YES', 2),
#  ('badges', 'name', 'character varying', 'YES', 3),
#  ('badges', 'date', 'timestamp without time zone', 'YES', 4),
#  ('badges', 'class', 'smallint', 'YES', 5),
#  ('badges', 'tagbased', 'boolean', 'YES', 6),
#  ('comments', 'id', 'integer', 'NO', 1),
#  ('comments', 'postid', 'integer', 'YES', 2),
#  ('comments', 'score', 'integer', 'YES', 3),
#  ('comments', 'text', 'character varying', 'YES', 4),
#  ('comments', 'creationdate', 'timestamp without time zone', 'YES', 5),
#  ('comments', 'userdisplayname', 'character varying', 'YES', 6),
#  ('comments', 'userid', 'integer', 'YES', 7),
#  ('companies', 'id', 'integer', 'NO', 1),
#  ('companies', 'name', 'character varying', 'NO', 2),
#  ('departments', 'dept_no', 'character', 'NO', 1),
#  ('departments', 'dept_name', 'character varying', 'NO', 2),
#  ('dept_emp', 'emp_no', 'integer', 'NO', 1),
#  ('dept_emp', 'dept_no', 'character', 'NO', 2),
#  ('dept_emp', 'from_date', 'date', 'NO', 3),
#  ('dept_emp', 'to_date', 'date', 'NO', 4),
#  ('dept_manager', 'emp_no', 'integer', 'NO', 1),
#  ('dept_manager', 'dept_no', 'character', 'NO', 2),
#  ('dept_manager', 'from_date', 'date', 'NO', 3),
#  ('dept_manager', 'to_date', 'date', 'NO', 4),
#  ('employees', 'emp_no', 'integer', 'NO', 1),
#  ('employees', 'birth_date', 'date', 'NO', 2),
#  ('employees', 'first_name', 'character varying', 'NO', 3),
#  ('employees', 'last_name', 'character varying', 'NO', 4),
#  ('employees', 'gender', 'USER-DEFINED', 'NO', 5),
#  ('employees', 'hire_date', 'date', 'NO', 6),
#  ('employees02', 'id', 'integer', 'NO', 1),
#  ('employees02', 'name', 'character varying', 'NO', 2),
#  ('employees02', 'job_id', 'integer', 'NO', 3),
#  ('inventory', 'id', 'integer', 'NO', 1),
#  ('inventory', 'name', 'character varying', 'YES', 2),
#  ('inventory', 'quantity', 'integer', 'YES', 3),
#  ('jobs', 'id', 'integer', 'NO', 1),
#  ('jobs', 'company_id', 'integer', 'NO', 2),
#  ('jobs', 'name', 'character varying', 'NO', 3),
#  ('jobs', 'salary', 'integer', 'NO', 4),
#  ('posthistory', 'id', 'integer', 'NO', 1),
#  ('posthistory', 'posthistorytypeid', 'smallint', 'YES', 2),
#  ('posthistory', 'postid', 'integer', 'YES', 3),
#  ('posthistory', 'revisionguid', 'uuid', 'YES', 4),
#  ('posthistory', 'creationdate', 'timestamp without time zone', 'YES', 5),
#  ('posthistory', 'userid', 'integer', 'YES', 6),
#  ('posthistory', 'userdisplayname', 'character varying', 'YES', 7),
#  ('posthistory', 'comment', 'character varying', 'YES', 8),
#  ('posthistory', 'text', 'character varying', 'YES', 9),
#  ('postlinks', 'id', 'integer', 'NO', 1),
#  ('postlinks', 'creationdate', 'timestamp without time zone', 'YES', 2),
#  ('postlinks', 'postid', 'integer', 'YES', 3),
#  ('postlinks', 'relatedpostid', 'integer', 'YES', 4),
#  ('postlinks', 'linktypeid', 'smallint', 'YES', 5),
#  ('posts', 'id', 'integer', 'NO', 1),
#  ('posts', 'posttypeid', 'smallint', 'YES', 2),
#  ('posts', 'acceptedanswerid', 'integer', 'YES', 3),
#  ('posts', 'parentid', 'integer', 'YES', 4),
#  ('posts', 'creationdate', 'timestamp without time zone', 'YES', 5),
#  ('posts', 'deletiondate', 'timestamp without time zone', 'YES', 6),
#  ('posts', 'score', 'integer', 'YES', 7),
#  ('posts', 'viewcount', 'integer', 'YES', 8),
#  ('posts', 'body', 'character varying', 'YES', 9),
#  ('posts', 'owneruserid', 'integer', 'YES', 10),
#  ('posts', 'ownerdisplayname', 'character varying', 'YES', 11),
#  ('posts', 'lasteditoruserid', 'integer', 'YES', 12),
#  ('posts', 'lasteditordisplayname', 'character varying', 'YES', 13),
#  ('posts', 'lasteditdate', 'timestamp without time zone', 'YES', 14),
#  ('posts', 'lastactivitydate', 'timestamp without time zone', 'YES', 15),
#  ('posts', 'title', 'character varying', 'YES', 16),
#  ('posts', 'tags', 'character varying', 'YES', 17),
#  ('posts', 'answercount', 'integer', 'YES', 18),
#  ('posts', 'commentcount', 'integer', 'YES', 19),
#  ('posts', 'favoritecount', 'integer', 'YES', 20),
#  ('posts', 'closeddate', 'timestamp without time zone', 'YES', 21),
#  ('posts', 'communityowneddate', 'timestamp without time zone', 'YES', 22),
#  ('released_by', 'release_id', 'integer', 'NO', 1),
#  ('released_by', 'artist_id', 'integer', 'NO', 2),
#  ('releases', 'release_id', 'integer', 'NO', 1),
#  ('releases', 'released', 'date', 'NO', 2),
#  ('releases', 'title', 'text', 'NO', 3),
#  ('releases', 'country', 'character varying', 'YES', 4),
#  ('releases', 'genre', 'character varying', 'NO', 5),
#  ('salaries', 'emp_no', 'integer', 'NO', 1),
#  ('salaries', 'salary', 'integer', 'NO', 2),
#  ('salaries', 'from_date', 'date', 'NO', 3),
#  ('salaries', 'to_date', 'date', 'NO', 4),
#  ('tags', 'id', 'integer', 'NO', 1),
#  ('tags', 'tagname', 'character varying', 'YES', 2),
#  ('tags', 'count', 'integer', 'YES', 3),
#  ('tags', 'excerptpostid', 'integer', 'YES', 4),
#  ('tags', 'wikipostid', 'integer', 'YES', 5),
#  ('titles', 'emp_no', 'integer', 'NO', 1),
#  ('titles', 'title', 'character varying', 'NO', 2),
#  ('titles', 'from_date', 'date', 'NO', 3),
#  ('titles', 'to_date', 'date', 'NO', 4),
#  ('tracks', 'release_id', 'integer', 'NO', 1),
#  ('tracks', 'position', 'character varying', 'YES', 2),
#  ('tracks', 'title', 'text', 'YES', 3),
#  ('tracks', 'duration', 'integer', 'YES', 4),
#  ('tracks', 'track_id', 'integer', 'NO', 5),
#  ('users', 'id', 'integer', 'NO', 1),
#  ('users', 'reputation', 'integer', 'YES', 2),
#  ('users', 'creationdate', 'timestamp without time zone', 'YES', 3),
#  ('users', 'displayname', 'character varying', 'YES', 4),
#  ('users', 'lastaccessdate', 'timestamp without time zone', 'YES', 5),
#  ('users', 'websiteurl', 'character varying', 'YES', 6),
#  ('users', 'location', 'character varying', 'YES', 7),
#  ('users', 'aboutme', 'character varying', 'YES', 8),
#  ('users', 'views', 'integer', 'YES', 9),
#  ('users', 'upvotes', 'integer', 'YES', 10),
#  ('users', 'downvotes', 'integer', 'YES', 11),
#  ('users', 'profileimageurl', 'character varying', 'YES', 12),
#  ('users', 'emailhash', 'character varying', 'YES', 13),
#  ('users', 'age', 'integer', 'YES', 14),
#  ('users', 'accountid', 'integer', 'YES', 15),
#  ('votes', 'id', 'integer', 'NO', 1),
#  ('votes', 'postid', 'integer', 'YES', 2),
#  ('votes', 'votetypeid', 'smallint', 'YES', 3),
#  ('votes', 'userid', 'integer', 'YES', 4),
#  ('votes', 'creationdate', 'timestamp without time zone', 'YES', 5),
#  ('votes', 'bountyamount', 'integer', 'YES', 6)]

# %% [markdown]
# ### Have a look at the datasets
# The following simple query gives the first 5 rows of the `artists` dataset

# %%
# %%sql
# SELECT * FROM artists LIMIT 5;
# Out:
#  * postgresql://postgres:***@db:5432/postgres
# 5 rows affected.
# [(1, 'The Persuader', 'Jesper Dahlbäck', None, None),
#  (2, 'Mr. James Barth & A.D.', 'Cari Lekebusch & Alexi Delano', None, None),
#  (3, 'Josh Wink', 'Joshua Winkelman', "After forming [l=Ovum Recordings] as an independent label in October 1994 with former partner [a=King Britt], Josh recorded the cult classic 'Liquid  ... (527 characters truncated) ... of attention trough his remixes for [a=FC Kahuna], [a=Paul Oakenfold], [a=Ladytron], [a=Clint Mansell], [a=Sting] and [a=Depeche Mode], among others.", 'http://www.joshwink.com/'),
#  (4, 'Johannes Heil', 'Johannes Heil', 'Electronic music producer, musician and live performer, born 3 February 1978 near the town of Bad Nauheim, Germany. Founder of [l=JH] and [l=Metatron Recordings].', 'http://johannes-heil.com/'),
#  (5, 'Heiko Laux', 'Heiko Laux', 'German DJ and producer based in Berlin. He is the founder of [l=Kanzleramt].', 'http://www.heiko-laux.com')]

# %% [markdown]
# Naturally we could write similar queries to better understand each of the other tables.

# %% [markdown]
# ### With what you now know about the datasets, try to answer the following questions
#
# 1. Which concepts are modelled in the dataset and how do they relate to each other? <b>Hint</b>: how do the tables connect logically?
# 2. Why do you think this shape (table) was chosen for the data and why not the other shapes?
# 3. In which normal forms are the corresponding relations?
# 4. How can we denormalise the data to make some queries more efficient? <b>Hint</b>: have a look at the queries in the next session of the exercises to see if adding some columns to some tables could reduce the need to `JOIN`.
# 5. What potential problems could result from adding redundancy?

# %% [markdown]
# ### Solution
# 1. The dataset contains data from the discogs. Artists, their details such as albums, salaries..., users of the platform...
# 2. We can define a Schema:
#    - The concepts (tables like artists and salaries) are fixed and limited.
#    - The attributes (columns like name and id) are also fixed and limited.
#    - The attributes have fixed data types.
#    - The different concepts are related to each other.
# 3. The relations are in 3NF:
#    - All relations are tabular => 1NF
#    - Relations have singular key ID => Attributes depends on all the prime attribtues => 2NF
#    - No transitive dependencies => 3NF
# 4. If we merge the artists with releases and tracks, we wouldn't have to join them every time.
# 5. Insert and Update anomaly.

# %% [markdown]
# ## Exercise 2: SQL warm-up
# Let us begin with several SQL queries to ease us back into the language.
#
# #### 1. Retrieve the artists with the name of 'Coldplay'.

# %%
# %%sql
# SELECT *
# FROM artists
# WHERE name = 'Coldplay';
# Out:
#  * postgresql://postgres:***@db:5432/postgres
# 1 rows affected.
# [(29735, 'Coldplay', None, "Coldplay is an English rock band from London, England. They've been a band since January 16, 1998 when they lost a demotape competition on XFM in Lon ... (128 characters truncated) ... itar\r Will Champion (William Champion) - Drums\r Guy Berryman (Guy Rupert Berryman) - Bass\r Chris Martin (Christopher Anthony John Martin) - Vocals", 'http://coldplay.com/')]

# %% [markdown]
# #### 2. List the titles of all releases by that artist in alphabetical order.
# <b>Hint</b>: Ignore the fact that different relases can have the same title.

# %%
# %%sql
# SELECT DISTINCT title
# FROM artists
# JOIN released_by USING(artist_id)
# JOIN releases USING(release_id)
# WHERE name = 'Coldplay'
# ORDER BY title;
# Out:
#  * postgresql://postgres:***@db:5432/postgres
# 40 rows affected.
# [('Acoustic',),
#  ('A Rush Of Blood To The Head',),
#  ('Boot Of Sound',),
#  ('Brothers & Sisters',),
#  ('Clocks',),
#  ('Clocks...',),
#  ('Clocks / Chime Trance Remixes',),
#  ('Clocks (Cosmos Rmx)',),
#  ('Clocks (Dean Coleman Remix)',),
#  ('Clocks (Planet Rockers Remixes)',),
#  ('Clocks (Remix)',),
#  ('Fix You',),
#  ("Flesh / Don't Need No Trouble",),
#  ('God',),
#  ('God Put A Smile Upon Your Face (Remixes)',),
#  ('In My Place',),
#  ('Murder Was The Bass / Clocks',),
#  ('One I Love',),
#  ('Parachutes',),
#  ('Remixes',),
#  ('Safety E.P.',),
#  ('Speed Of Sound',),
#  ('Speed Of Sound (2005 House Remixes)',),
#  ('Speed Of Sound (Karl G Remix)',),
#  ('Talk',),
#  ('Talk (Remixes)',),
#  ('Talk (Spencer Collective Mixes)',),
#  ('Talk - The Remixes',),
#  ('Talk (Thin White Duke Remix)',),
#  ('The Blue Room E.P.',),
#  ('The Metric System EP',),
#  ('The Scientist',),
#  ('Time',),
#  ('Trouble',),
#  ('Trouble / Clocks',),
#  ('Trouble In Paradise',),
#  ('Trouble - Norwegian Live EP',),
#  ('X&Y',),
#  ('X&Y (Special Dutch Edition)',),
#  ('Yellow',)]

# %% [markdown]
# #### 3. How many tracks from 'Coldplay' have position '1'?

# %%
# %%sql
# SELECT COUNT(*)
# FROM artists
# JOIN released_by USING(artist_id)
# JOIN releases USING(release_id)
# JOIN tracks USING(release_id)
# WHERE name = 'Coldplay' AND position = '1';
# Out:
#  * postgresql://postgres:***@db:5432/postgres
# 1 rows affected.
# [(32,)]

# %% [markdown]
# #### 4. What is the average track duration?

# %%
# %%sql
# SELECT AVG(CAST(duration as FLOAT))
# FROM tracks;
# Out:
#  * postgresql://postgres:***@db:5432/postgres
# 1 rows affected.
# [(324.59572773212363,)]

# %% [markdown]
# #### 5. How many artists have released tracks longer than twice the average?

# %%
# %%sql
# WITH average_duration AS (SELECT AVG(CAST(duration as FLOAT)) FROM tracks)
#
# SELECT COUNT(DISTINCT artist_id)
# FROM artists
# JOIN released_by USING(artist_id)
# JOIN tracks USING(release_id)
# WHERE duration > 2*(SELECT * FROM average_duration);
# Out:
#  * postgresql://postgres:***@db:5432/postgres
# 1 rows affected.
# [(18894,)]

# %% [markdown]
# ## Exercise 3: more SQL
# We will now see more complex SQL queries.

# %% [markdown]
# #### 1. What is the title of the album from 'Coldplay' with the most amount of tracks?

# %%
# %%sql
# WITH tracks_amount AS(SELECT releases.title AS album, COUNT(*) as number_of_tracks
#                      FROM artists
#                      JOIN released_by USING(artist_id)
#                      JOIN releases USING(release_id)
#                      JOIN tracks USING(release_id)
#                      WHERE name = 'Coldplay'
#                      GROUP BY releases.release_id)
#
# SELECT album, number_of_tracks
# FROM tracks_amount
# WHERE number_of_tracks = (SELECT MAX(number_of_tracks)
#                          FROM tracks_amount);
# Out:
#  * postgresql://postgres:***@db:5432/postgres
# 1 rows affected.
# [('X&Y (Special Dutch Edition)', 19)]

# %% [markdown]
# #### 2. How many artists have released an album with total track duration above twice the average total track duration?
#
# <b>Hint</b>: this is not the same as exercise 2.5 since we are lookong at the <b>total</b> track duration of the album.

# %%
# %%sql
# WITH album_duration AS (SELECT release_id, SUM(duration) as duration
#                        FROM tracks
#                        GROUP BY release_id),
# average AS (SELECT AVG(duration)
#            FROM album_duration)
#
# SELECT COUNT(DISTINCT(artists.artist_id))
# FROM artists
# JOIN released_by USING(artist_id)
# JOIN album_duration USING(release_id)
# WHERE duration > 2 * (SELECT * from average)
# Out:
#  * postgresql://postgres:***@db:5432/postgres
# 1 rows affected.
# [(16426,)]

# %% [markdown]
# #### 3. How many artists have both a release with a track longer than average and one with total duration longer than average?
#
# <b>Hint</b>: you can use `INTERSECT` or `EXISTS` to write your query.

# %%
# %%sql
# WITH average_track AS (SELECT AVG(CAST(duration as FLOAT)) FROM tracks),
#
# album_duration AS (SELECT release_id, SUM(duration) as duration
#                    FROM tracks
#                    GROUP BY release_id),
#
# album_average AS (SELECT AVG(duration)
#                   FROM album_duration),
#
# artist_intersection AS (
#     SELECT DISTINCT(artist_id)
#     FROM artists
#     JOIN released_by USING(artist_id)
#     JOIN tracks USING(release_id)
#     WHERE duration > 2 * (SELECT * FROM average_track)
#     INTERSECT
#     SELECT DISTINCT(artist_id)
#     FROM artists
#     JOIN released_by USING(artist_id)
#     JOIN album_duration USING(release_id)
#     WHERE duration > 2 * (SELECT * from album_average))
#
# SELECT COUNT(*)
# FROM artist_intersection;
# Out:
#  * postgresql://postgres:***@db:5432/postgres
# 1 rows affected.
# [(8146,)]

# %% [markdown]
# #### 4. Show the artists have more than 200 releases in total but have no releases with the genre 'Pop' in reversed alphabetical order.

# %%
# %%sql
# WITH big_artists AS(
#     SELECT artist_id, name, COUNT(*) AS count
#     FROM artists
#     NATURAL JOIN released_by
#     NATURAL JOIN releases
#     GROUP BY artist_id
#     HAVING COUNT(release_id)>200)
#
# SELECT name, count
# FROM big_artists
# WHERE artist_id NOT IN (SELECT artist_id
#                        FROM artists NATURAL JOIN released_by NATURAL JOIN releases
#                        WHERE genre = 'Pop')
# ORDER BY name DESC;
# Out:
#  * postgresql://postgres:***@db:5432/postgres
# 35 rows affected.
# [('Yello', 275),
#  ('WestBam', 236),
#  ('Underworld', 273),
#  ('U2', 365),
#  ('The Shamen', 221),
#  ('The Prodigy', 355),
#  ('The Human League', 210),
#  ('The Cure', 417),
#  ('The Chemical Brothers', 302),
#  ('The Beatles', 205),
#  ('The Art Of Noise', 238),
#  ('Technotronic', 226),
#  ('Tangerine Dream', 295),
#  ('Scooter', 252),
#  ('Sash!', 214),
#  ('Pet Shop Boys', 600),
#  ('Paul van Dyk', 274),
#  ('Orchestral Manoeuvres In The Dark', 260),
#  ('Orbital', 236),
#  ('Moby', 546),
#  ('Mauro Picotto', 210),
#  ('Kraftwerk', 349),
#  ('Kool & The Gang', 203),
#  ('Jean-Michel Jarre', 223),
#  ('Jamiroquai', 262),
#  ('James Brown', 201),
#  ('Faithless', 336),
#  ('Erasure', 448),
#  ('DJ Tiësto', 261),
#  ('Depeche Mode', 1053),
#  ('De La Soul', 205),
#  ('Beastie Boys', 221),
#  ('ATB', 213),
#  ('Armand Van Helden', 245),
#  ('2 Unlimited', 256)]

# %% [markdown]
# ## Exercise 4: Discuss query patterns and language features of SQL
# 1. What patterns did you use in many of the queries above?
#
# 2. What is the usual pattern of an SQL query? Which operations happen pre-grouping and which ones post-grouping?
#
# 3. What makes SQL a declarative language and what advantages does that have?
#
# 4. What makes SQL a functional language and what advantages does that have?
#
# 5. How would the denormalization we talked about previously simplify the queries?

# %% [markdown]
# ### Solution
# 1. SELECT, PROJECT, JOIN, GROUP, ORDER.
# 2. The usual pattern is SELECT, FROM, JOIN, WHERE, GROUP BY, HAVING, ORDER BY, LIMIT, OFFSET. FROM and WHERE happen pre-grouping.
# 3. Declarative: we declare what we want and not how we want to get it.
# 4. Functional: Because we can use result of SQL (With) as input to other queries.
# 5. No need to JOIN.

# %% [markdown]
# ## Exercise 5: Limits of SQL (optional)
# Explain what the following query does.
# <b>Hints</b>: The query treats the data as if it was in graph shape.

# %%
# %%sql
# WITH RECURSIVE
#     X AS (SELECT 3 AS Value),
#     artist_releases AS (
#         SELECT artists.artist_id, artists.name, releases.release_id, releases.title
#         FROM artists, released_by, releases
#         WHERE artists.artist_id = released_by.artist_id
#         AND released_by.release_id = releases.release_id
#     ),
#     collaborations AS (
#         SELECT DISTINCT ar1.artist_id AS left_id, ar1.name AS left_name,
#                 ar2.artist_id AS right_id, ar2.name AS right_name, 1 AS distance
#         FROM artist_releases AS ar1, artist_releases AS ar2
#         WHERE ar1.release_id = ar2.release_id
#         AND ar1.artist_id != ar2.artist_id
#     ),
#     X_hop_collaborations AS (
#         SELECT * FROM collaborations  -- base case
#         UNION
#         SELECT c1.left_id, c1.left_name, c2.right_id, c2.right_name, c1.distance + 1 AS distance
#         FROM X_hop_collaborations AS c1
#         JOIN collaborations c2 ON c1.right_id = c2.left_id
#         WHERE c1.distance < (SELECT * FROM X)
#     )
# SELECT *
# FROM X_hop_collaborations
# WHERE left_name = 'Coldplay'
# ORDER BY distance, right_name;
# Out:
#  * postgresql://postgres:***@db:5432/postgres
# 146 rows affected.
# [(29735, 'Coldplay', 124541, 'Bon Jovi', 1),
#  (29735, 'Coldplay', 1654, 'DK', 1),
#  (29735, 'Coldplay', 392179, 'G Synth', 1),
#  (29735, 'Coldplay', 10916, 'Jan Johnston', 1),
#  (29735, 'Coldplay', 12236, 'Marco V', 1),
#  (29735, 'Coldplay', 4213, 'Max Graham', 1),
#  (29735, 'Coldplay', 92827, 'Michelle Nicol', 1),
#  (29735, 'Coldplay', 1279, 'Orbital', 1),
#  (29735, 'Coldplay', 239326, 'Walsh & Coutre', 1),
#  (29735, 'Coldplay', 10785, 'Angelo Badalamenti', 2),
#  (29735, 'Coldplay', 41436, 'Benjamin Bates', 2),
#  (29735, 'Coldplay', 124541, 'Bon Jovi', 2),
#  (29735, 'Coldplay', 2737, 'BT', 2),
#  (29735, 'Coldplay', 29735, 'Coldplay', 2),
#  (29735, 'Coldplay', 184852, 'Cor Fijneman', 2),
#  (29735, 'Coldplay', 11101, 'Cosmic Gate', 2),
#  (29735, 'Coldplay', 981, 'Cylob', 2),
#  (29735, 'Coldplay', 1654, 'DK', 2),
#  (29735, 'Coldplay', 7090, 'Freefall', 2),
#  (29735, 'Coldplay', 392179, 'G Synth', 2),
#  (29735, 'Coldplay', 5922, 'Hole In One', 2),
#  (29735, 'Coldplay', 71790, 'Holly', 2),
#  (29735, 'Coldplay', 2604010, 'Jada (7)', 2),
#  (29735, 'Coldplay', 5568, 'Jamie Myerson', 2),
#  (29735, 'Coldplay', 8118, 'Jens', 2),
#  (29735, 'Coldplay', 287990, 'Jessica Jacobs', 2),
#  (29735, 'Coldplay', 18836, 'Kirk Hammett', 2),
#  (29735, 'Coldplay', 11749, 'Knuckleheadz', 2),
#  (29735, 'Coldplay', 789, "Lil' Louis", 2),
#  (29735, 'Coldplay', 12236, 'Marco V', 2),
#  (29735, 'Coldplay', 4480, 'Massive Attack', 2),
#  (29735, 'Coldplay', 106802, 'Michael Kamen', 2),
#  (29735, 'Coldplay', 34583, 'Mike Flowers', 2),
#  (29735, 'Coldplay', 90120, 'Ron van den Beuken', 2),
#  (29735, 'Coldplay', 80936, 'Scott Bond', 2),
#  (29735, 'Coldplay', 238694, 'Serge Devant', 2),
#  (29735, 'Coldplay', 166466, 'Skip Raiders', 2),
#  (29735, 'Coldplay', 9435, 'Starecase', 2),
#  (29735, 'Coldplay', 24609, 'Sub•Merge', 2),
#  (29735, 'Coldplay', 19083, 'Svenson & Gielen', 2),
#  (29735, 'Coldplay', 32480, 'Therapy?', 2),
#  (29735, 'Coldplay', 11693, 'Tomski', 2),
#  (29735, 'Coldplay', 50263, 'Yes', 2),
#  (29735, 'Coldplay', 37722, 'Anita Kelsey', 3),
#  (29735, 'Coldplay', 9651, 'Beat Foundation', 3),
#  (29735, 'Coldplay', 41436, 'Benjamin Bates', 3),
#  (29735, 'Coldplay', 52835, 'Beyoncé', 3),
#  (29735, 'Coldplay', 982, 'Bochum Welt', 3),
#  (29735, 'Coldplay', 124541, 'Bon Jovi', 3),
#  (29735, 'Coldplay', 2737, 'BT', 3),
#  (29735, 'Coldplay', 14396, 'Carlton', 3),
#  (29735, 'Coldplay', 50676, 'Carol Tripp', 3),
#  (29735, 'Coldplay', 1865, 'Chestnut', 3),
#  (29735, 'Coldplay', 11438, 'Choci', 3),
#  (29735, 'Coldplay', 110405, 'Clokx', 3),
#  (29735, 'Coldplay', 29735, 'Coldplay', 3),
#  (29735, 'Coldplay', 11101, 'Cosmic Gate', 3),
#  (29735, 'Coldplay', 981, 'Cylob', 3),
#  (29735, 'Coldplay', 40062, 'Daddy G', 3),
#  (29735, 'Coldplay', 5867, 'Dave Seaman', 3),
#  (29735, 'Coldplay', 47572, 'David Lynch', 3),
#  (29735, 'Coldplay', 7624, 'David Morales', 3),
#  (29735, 'Coldplay', 24085, 'Defective Audio', 3),
#  (29735, 'Coldplay', 34919, 'DJ Dazzle', 3),
#  (29735, 'Coldplay', 27737, 'DJ Shog', 3),
#  (29735, 'Coldplay', 6197, 'DJ Tiësto', 3),
#  (29735, 'Coldplay', 29121, 'DJ Work!', 3),
#  (29735, 'Coldplay', 1654, 'DK', 3),
#  (29735, 'Coldplay', 983, 'DMX Krew', 3),
#  (29735, 'Coldplay', 11573, 'Dynamic Intervention', 3),
#  (29735, 'Coldplay', 125549, 'Eddie Halliwell', 3),
#  (29735, 'Coldplay', 5541, 'Enzo Scifo', 3),
#  (29735, 'Coldplay', 195359, 'Fatkid', 3),
#  (29735, 'Coldplay', 143244, 'Filo & Peri', 3),
#  (29735, 'Coldplay', 2447, 'Frankie Knuckles', 3),
#  (29735, 'Coldplay', 7090, 'Freefall', 3),
#  (29735, 'Coldplay', 9709, 'Grace', 3),
#  (29735, 'Coldplay', 392179, 'G Synth', 3),
#  (29735, 'Coldplay', 13141, 'House Of Gypsies', 3),
#  (29735, 'Coldplay', 13686, 'Hydrogen Rockers', 3),
#  (29735, 'Coldplay', 15736, 'Impact', 3),
#  (29735, 'Coldplay', 2604010, 'Jada (7)', 3),
#  (29735, 'Coldplay', 36377, 'James Lawson', 3),
#  (29735, 'Coldplay', 10916, 'Jan Johnston', 3),
#  (29735, 'Coldplay', 36828, 'Jase From Outta Space', 3),
#  (29735, 'Coldplay', 21742, 'Jay-Z', 3),
#  (29735, 'Coldplay', 8118, 'Jens', 3),
#  (29735, 'Coldplay', 249307, 'Joe Murena', 3),
#  (29735, 'Coldplay', 23555, 'John Kelly', 3),
#  (29735, 'Coldplay', 3, 'Josh Wink', 3),
#  (29735, 'Coldplay', 18353, 'Justin Bourne', 3),
#  (29735, 'Coldplay', 89109, 'Kaleb', 3),
#  (29735, 'Coldplay', 5525, 'KGB', 3),
#  (29735, 'Coldplay', 1399, 'Kirsty Hawkshaw', 3),
#  (29735, 'Coldplay', 13608, 'Kylie Minogue', 3),
#  (29735, 'Coldplay', 4853161, 'Lakota (3)', 3),
#  (29735, 'Coldplay', 789, "Lil' Louis", 3),
#  (29735, 'Coldplay', 242361, 'Lonely Heart Rockers', 3),
#  (29735, 'Coldplay', 7870, 'Mad Professor', 3),
#  (29735, 'Coldplay', 12236, 'Marco V', 3),
#  (29735, 'Coldplay', 448196, 'Mark Eteson', 3),
#  (29735, 'Coldplay', 223468, 'Mark N-R-G', 3),
#  (29735, 'Coldplay', 52687, 'Matt Hardwick', 3),
#  (29735, 'Coldplay', 4213, 'Max Graham', 3),
#  (29735, 'Coldplay', 133108, 'MC Marxman', 3),
#  (29735, 'Coldplay', 18839, 'Metallica', 3),
#  (29735, 'Coldplay', 492415, 'Michelangelo (2)', 3),
#  (29735, 'Coldplay', 92827, 'Michelle Nicol', 3),
#  (29735, 'Coldplay', 462377, 'Mike Doughty', 3),
#  (29735, 'Coldplay', 34583, 'Mike Flowers', 3),
#  (29735, 'Coldplay', 5648, 'Mos Def', 3),
#  (29735, 'Coldplay', 2446, 'Mr. Fingers', 3),
#  (29735, 'Coldplay', 114414, 'Nemesis', 3),
#  (29735, 'Coldplay', 1279, 'Orbital', 3),
#  (29735, 'Coldplay', 52197, 'Oscar G & Ralph Falcon', 3),
#  (29735, 'Coldplay', 1049, 'Paul van Dyk', 3),
#  (29735, 'Coldplay', 269548, 'Peace Together', 3),
#  (29735, 'Coldplay', 38910, 'Prime Mover', 3),
#  (29735, 'Coldplay', 64575, 'Project Mayhem', 3),
#  (29735, 'Coldplay', 64583, 'Q:Dos', 3),
#  (29735, 'Coldplay', 152426, 'Q. Lazzarus', 3),
#  (29735, 'Coldplay', 92476, 'Red Hot Chili Peppers', 3),
#  (29735, 'Coldplay', 44903, 'Renato Cohen', 3),
#  (29735, 'Coldplay', 30543, 'Rhyme Time Productions', 3),
#  (29735, 'Coldplay', 226992, 'Romy (2)', 3),
#  (29735, 'Coldplay', 90120, 'Ron van den Beuken', 3),
#  (29735, 'Coldplay', 30515, 'Sadie Glutz', 3),
#  (29735, 'Coldplay', 45254, 'Salez', 3),
#  (29735, 'Coldplay', 162952, 'Sam Sharp', 3),
#  (29735, 'Coldplay', 80936, 'Scott Bond', 3),
#  (29735, 'Coldplay', 166466, 'Skip Raiders', 3),
#  (29735, 'Coldplay', 869, 'Steve Poindexter', 3),
#  (29735, 'Coldplay', 16794, 'Sylvester', 3),
#  (29735, 'Coldplay', 11887, 'Talla 2XLC', 3),
#  (29735, 'Coldplay', 5355, 'Terry Callier', 3),
#  (29735, 'Coldplay', 269254, 'The London Philharmonic Orchestra', 3),
#  (29735, 'Coldplay', 317584, 'The San Francisco Symphony Orchestra', 3),
#  (29735, 'Coldplay', 25501, 'Tillmann Uhrmacher', 3),
#  (29735, 'Coldplay', 171, 'Tim Deluxe', 3),
#  (29735, 'Coldplay', 51039, 'Tom Jones', 3),
#  (29735, 'Coldplay', 9902, 'Tori Amos', 3),
#  (29735, 'Coldplay', 2541, 'Tracey Thorn', 3),
#  (29735, 'Coldplay', 6577, 'Tsunami One', 3),
#  (29735, 'Coldplay', 78755, 'Vincent Covello', 3),
#  (29735, 'Coldplay', 239326, 'Walsh & Coutre', 3),
#  (29735, 'Coldplay', 2893, 'Woody McBride', 3)]

# %% [markdown]
# ### Solution
